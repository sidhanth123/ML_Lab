# %% [markdown]
# <a href="https://colab.research.google.com/github/sidhanth123/ML_Lab/blob/main/Decision_Tree.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from sklearn.tree import DecisionTreeClassifier, plot_tree
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, confusion_matrix
import matplotlib.pyplot as plt

# %%
url = "/content/diabetes.csv"

# %%
cols = ['Pregnancies','Glucose', 'BloodPressure', 'SkinThickness', 'Insulin',
        'BMI', 'DiabetesPedigreeFunction', 'Age', 'Outcome']

# %%
cols
# Out:
# ['Pregnancies',
#  'Glucose',
#  'BloodPressure',
#  'SkinThickness',
#  'Insulin',
#  'BMI',
#  'DiabetesPedigreeFunction',
#  'Age',
#  'Outcome']

# %%
df = pd.read_csv(url, header=None, names=cols)
df = df.iloc[1:]

# %%
X = df.drop("Outcome", axis=1)
y = df["Outcome"]

# %%
X
# Out:
#     Pregnancies Glucose BloodPressure SkinThickness Insulin   BMI  \
# 1             6     148            72            35       0  33.6
# 2             1      85            66            29       0  26.6
# 3             8     183            64             0       0  23.3
# 4             1      89            66            23      94  28.1
# 5             0     137            40            35     168  43.1
# ..          ...     ...           ...           ...     ...   ...
# 764          10     101            76            48     180  32.9
# 765           2     122            70            27       0  36.8
# 766           5     121            72            23     112  26.2
# 767           1     126            60             0       0  30.1
# 768           1      93            70            31       0  30.4
#
#     DiabetesPedigreeFunction Age
# 1                      0.627  50
# 2                      0.351  31
# 3                      0.672  32
# 4                      0.167  21
# ...

# %%
y
# Out:
# 1      1
# 2      0
# 3      1
# 4      0
# 5      1
#       ..
# 764    0
# 765    0
# 766    0
# 767    1
# 768    0
# Name: Outcome, Length: 768, dtype: object

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
X_train
# Out:
#     Pregnancies Glucose BloodPressure SkinThickness Insulin   BMI  \
# 335           1      95            60            18      58  23.9
# 140           5     105            72            29     325  36.9
# 486           0     135            68            42     250  42.3
# 548           4     131            68            21     166  33.1
# 19            1     103            30            38      83  43.3
# ..          ...     ...           ...           ...     ...   ...
# 72            5     139            64            35     140  28.6
# 107           1      96           122             0       0  22.4
# 271          10     101            86            37       0  45.6
# 436           0     141             0             0       0  42.4
# 103           0     125            96             0       0  22.5
#
#     DiabetesPedigreeFunction Age
# 335                     0.26  22
# 140                    0.159  28
# 486                    0.365  24
# 548                     0.16  28
# ...

# %%
X_test
# Out:
#     Pregnancies Glucose BloodPressure SkinThickness Insulin   BMI  \
# 669           6      98            58            33     190    34
# 325           2     112            75            32       0  35.7
# 625           2     108            64             0       0  30.8
# 691           8     107            80             0       0  24.6
# 474           7     136            90             0       0  29.9
# ..          ...     ...           ...           ...     ...   ...
# 620           0     119             0             0       0  32.4
# 199           4     109            64            44      99  34.8
# 539           0     127            80            37     210  36.3
# 330           6     105            70            32      68  30.8
# 303           5      77            82            41      42  35.8
#
#     DiabetesPedigreeFunction Age
# 669                     0.43  43
# 325                    0.148  21
# 625                    0.158  21
# 691                    0.856  34
# ...

# %%
y_train
# Out:
# 335    0
# 140    0
# 486    1
# 548    0
# 19     0
#       ..
# 72     0
# 107    0
# 271    1
# 436    1
# 103    0
# Name: Outcome, Length: 537, dtype: object

# %%
y_test
# Out:
# 669    0
# 325    0
# 625    0
# 691    0
# 474    0
#       ..
# 620    1
# 199    1
# 539    0
# 330    0
# 303    0
# Name: Outcome, Length: 231, dtype: object

# %%
clf = DecisionTreeClassifier(criterion='entropy', max_depth = 3, random_state = 42)
clf.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy', max_depth=3, random_state=42)

# %%
y_pred = clf.predict(X_test)
print("Accuracy:", accuracy_score(y_test, y_pred))
print("Confusion Matrix:\n", confusion_matrix(y_test, y_pred))
# Out:
# Accuracy: 0.7186147186147186
# Confusion Matrix:
#  [[141  10]
#  [ 55  25]]

# %%
plt.figure(figsize=(20,10))
plot_tree(clf, feature_names=X.columns, class_names=["Non-Diabetic", "Diabetic"], filled=True)
plt.show()

# %%
df = pd.read_csv(url, header=None, names=cols)
display(df)
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI
# 1              6      148             72             35        0  33.6
# 2              1       85             66             29        0  26.6
# 3              8      183             64              0        0  23.3
# 4              1       89             66             23       94  28.1
# ..           ...      ...            ...            ...      ...   ...
# 764           10      101             76             48      180  32.9
# 765            2      122             70             27        0  36.8
# 766            5      121             72             23      112  26.2
# 767            1      126             60              0        0  30.1
# 768            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0    DiabetesPedigreeFunction  Age  Outcome
# ...
